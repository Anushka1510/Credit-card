# %%
import pandas as pd
import numpy as np
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1b67a093-109b-436e-ae7f-9b81007afa36" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1b67a093-109b-436e-ae7f-9b81007afa36">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# input excel file path
inputExcelFile ="Creditcard.xlsx"

# Reading an excel file
excelFile = pd.read_excel (inputExcelFile)

# Converting excel file into CSV file
excelFile.to_csv ("Creditcard.csv", index = None, header=True)

# Reading and Converting the output csv file into a dataframe object
dataframeObject = pd.DataFrame(pd.read_csv("Credit card.csv"))

# Displaying the dataframe object
dataframeObject
# Out:
#      step      type     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0       1   PAYMENT    9839.64  C1231006815       170136.0       160296.36
# 1       1   PAYMENT    1864.28  C1666544295        21249.0        19384.72
# 2       1  TRANSFER     181.00  C1305486145          181.0            0.00
# 3       1  CASH_OUT     181.00   C840083671          181.0            0.00
# 4       1   PAYMENT   11668.14  C2048537720        41554.0        29885.86
# ..    ...       ...        ...          ...            ...             ...
# 694     1  CASH_OUT  244361.81  C1191864687            0.0            0.00
# 695     1  CASH_OUT  596617.87   C466032056            0.0            0.00
# 696     1  CASH_OUT  108600.78   C690822257            0.0            0.00
# 697     1  CASH_OUT  377520.94   C726212590            0.0            0.00
# 698     1  CASH_OUT   60758.42  C1058822905            0.0            0.00
#
# ...

# %%
df = pd.read_csv("Creditcard.csv")
df.head()
df.shape
# Out:
# (699, 11)

# %%
df.iloc[0:10,:]
df.iloc[:,:]
df.iloc[10:,:10]
# Out:
#      step      type     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 10      1     DEBIT    9644.94  C1900366749         4465.0            0.00
# 11      1   PAYMENT    3099.97   C249177573        20771.0        17671.03
# 12      1   PAYMENT    2560.74  C1648232591         5070.0         2509.26
# 13      1   PAYMENT   11633.76  C1716932897        10127.0            0.00
# 14      1   PAYMENT    4098.78  C1026483832       503264.0       499165.22
# ..    ...       ...        ...          ...            ...             ...
# 694     1  CASH_OUT  244361.81  C1191864687            0.0            0.00
# 695     1  CASH_OUT  596617.87   C466032056            0.0            0.00
# 696     1  CASH_OUT  108600.78   C690822257            0.0            0.00
# 697     1  CASH_OUT  377520.94   C726212590            0.0            0.00
# 698     1  CASH_OUT   60758.42  C1058822905            0.0            0.00
#
#         nameDest  oldbalanceDest  newbalanceDest  isFraud
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt



# load the dataset
df = pd.read_csv("Creditcard.csv")

# display 5 rows of dataset
df.head()

df.boxplot(by ='oldbalanceOrg', column =['newbalanceOrig'], grid = False)
# Out:
# <Axes: title={'center': 'newbalanceOrig'}, xlabel='oldbalanceOrg'>

# %%
import matplotlib.pyplot as plt
# plot a histogram
df['oldbalanceOrg'].hist(bins=10)

# shows presence of a lot of outliers/extreme values
df.boxplot(column='oldbalanceOrg', by = 'newbalanceOrig')

# plotting points as a scatter plot
x = df["oldbalanceOrg"]
y = df["newbalanceOrig"]
plt.scatter(x, y, label= "stars", color= "m",
            marker= "*", s=30)
# x-axis label
plt.xlabel('oldbalanceOrg')
# frequency label
plt.ylabel('newbalanceOrig')
# function to show the plot
plt.show()

# %%
# making data frame from csv file
data = pd.read_csv("Creditcard.csv")

# creating bool series True for NaN values
bool_series = pd.isnull(data["newbalanceDest"])


data[bool_series]
# Out:
# Empty DataFrame
# Columns: [step, type, amount, nameOrig, oldbalanceOrg, newbalanceOrig, nameDest, oldbalanceDest, newbalanceDest, isFraud, Unnamed: 10]
# Index: []
